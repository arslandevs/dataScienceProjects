# %% [markdown]
# This notebook:
# 1.  Drops device_id as redundant
# 2.  Converts 4 time features to datetime
# 3.  Converts burn_material_amount to float
# 4.  Leaves hotplate_temp as string
# 5.  Leaves distance_sensor_hotplate
# 4.  Encodes specimen_class as encoded_specimen and drops the former
#     in_smoke: 1, clean_air: 0
# 5.  Drops burn_material_name since it is exactly the same as burn_material

# %%
import pandas as pd
import os

# %%
input_file = '../AA Dataset/aa_dryad_merged_cleaned_data2_update.csv'
output_file = '../AA Dataset/aa_dryad_merged_cleaned_data2_update.csv'

# %%
df = pd.read_csv(input_file)

# %%
df.head()
# Out:
#    sensor_node_id                             device_id  \
# 0             146  me-sylvav1n21-e637a6d4-30ee-49a6-8ad
# 1             146  me-sylvav1n21-e637a6d4-30ee-49a6-8ad
# 2             146  me-sylvav1n21-e637a6d4-30ee-49a6-8ad
# 3             146  me-sylvav1n21-e637a6d4-30ee-49a6-8ad
# 4             146  me-sylvav1n21-e637a6d4-30ee-49a6-8ad
#
#                        scan_time  temp_0  temp_1  temp_2  temp_3  temp_4  \
# 0  2021-09-01 09:01:36.817528009    18.8    19.0    19.6    19.6    19.7
# 1  2021-09-01 09:02:13.375891000    19.2    19.3    19.8    19.8    19.9
# 2  2021-09-01 09:02:50.057426000    19.3    19.4    19.9    19.9    20.0
# 3  2021-09-01 09:03:26.565743000    19.3    19.5    20.0    20.0    20.1
# 4  2021-09-01 09:04:03.635421991    19.4    19.5    20.0    20.0    20.1
#
#    temp_5  temp_6  ...                       end_time  burn_material  \
# 0    20.0    20.1  ...  2021-09-01 18:50:46.000000000            SP2
# 1    20.2    20.2  ...  2021-09-01 18:50:46.000000000            SP2
# 2    20.3    20.3  ...  2021-09-01 18:50:46.000000000            SP2
# 3    20.3    20.4  ...  2021-09-01 18:50:46.000000000            SP2
# 4    20.4    20.4  ...  2021-09-01 18:50:46.000000000            SP2
#
#    burn_material_name  burn_material_amount                 hotplate_start  \
# 0                 SP2                  600g  2021-09-01 10:03:57.000000000
# 1                 SP2                  600g  2021-09-01 10:03:57.000000000
# 2                 SP2                  600g  2021-09-01 10:03:57.000000000
# 3                 SP2                  600g  2021-09-01 10:03:57.000000000
# 4                 SP2                  600g  2021-09-01 10:03:57.000000000
#
#    hotplate_temp  distance_sensor_hotplate  venue  venue_type  specimen_class
# 0            500                       30m   hall        Hall       clean_air
# 1            500                       30m   hall        Hall       clean_air
# 2            500                       30m   hall        Hall       clean_air
# 3            500                       30m   hall        Hall       clean_air
# 4            500                       30m   hall        Hall       clean_air
#
# [5 rows x 47 columns]

# %%
df.shape
# Out:
# (2498, 47)

# %%
df.columns
# Out:
# Index(['sensor_node_id', 'device_id', 'scan_time', 'temp_0', 'temp_1',
#        'temp_2', 'temp_3', 'temp_4', 'temp_5', 'temp_6', 'temp_7', 'temp_8',
#        'temp_9', 'humid_0', 'humid_1', 'humid_2', 'humid_3', 'humid_4',
#        'humid_5', 'humid_6', 'humid_7', 'humid_8', 'humid_9', 'gas_scan_0',
#        'gas_scan_1', 'gas_scan_2', 'gas_scan_3', 'gas_scan_4', 'gas_scan_5',
#        'gas_scan_6', 'gas_scan_7', 'gas_scan_8', 'gas_scan_9', 'gas_scan_cnt',
#        'trigger', 'experiment_id', 'start_time', 'end_time', 'burn_material',
#        'burn_material_name', 'burn_material_amount', 'hotplate_start',
#        'hotplate_temp', 'distance_sensor_hotplate', 'venue', 'venue_type',
#        'specimen_class'],
#       dtype='object')

# %% [markdown]
# Drop device_id since it is synonymous with sensor_node_id

# %%
df = df.drop(['device_id'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sensor_node_id            2498 non-null   int64
#  1   scan_time                 2498 non-null   object
#  2   temp_0                    2498 non-null   float64
#  3   temp_1                    2498 non-null   float64
#  4   temp_2                    2498 non-null   float64
#  5   temp_3                    2498 non-null   float64
#  6   temp_4                    2498 non-null   float64
#  7   temp_5                    2498 non-null   float64
#  8   temp_6                    2498 non-null   float64
#  9   temp_7                    2498 non-null   float64
#  10  temp_8                    2498 non-null   float64
#  11  temp_9                    2498 non-null   float64
#  12  humid_0                   2498 non-null   float64
#  13  humid_1                   2498 non-null   float64
#  14  humid_2                   2498 non-null   float64
#  15  humid_3                   2498 non-null   float64
#  16  humid_4                   2498 non-null   float64
#  17  humid_5                   2498 non-null   float64
#  18  humid_6                   2498 non-null   float64
#  19  humid_7                   2498 non-null   float64
#  20  humid_8                   2498 non-null   float64
#  21  humid_9                   2498 non-null   float64
#  22  gas_scan_0                2498 non-null   float64
#  23  gas_scan_1                2498 non-null   float64
#  24  gas_scan_2                2498 non-null   float64
#  25  gas_scan_3                2498 non-null   float64
#  26  gas_scan_4                2498 non-null   float64
#  27  gas_scan_5                2498 non-null   float64
#  28  gas_scan_6                2498 non-null   float64
#  29  gas_scan_7                2498 non-null   float64
#  30  gas_scan_8                2498 non-null   float64
#  31  gas_scan_9                2498 non-null   float64
#  32  gas_scan_cnt              2498 non-null   float64
#  33  trigger                   2498 non-null   object
#  34  experiment_id             2498 non-null   int64
#  35  start_time                2498 non-null   object
#  36  end_time                  2498 non-null   object
#  37  burn_material             2498 non-null   object
#  38  burn_material_name        2498 non-null   object
#  39  burn_material_amount      2070 non-null   object
#  40  hotplate_start            2498 non-null   object
#  41  hotplate_temp             2498 non-null   object
#  42  distance_sensor_hotplate  2498 non-null   object
#  43  venue                     2498 non-null   object
#  44  venue_type                2498 non-null   object
#  45  specimen_class            2498 non-null   object
# dtypes: float64(31), int64(2), object(13)
# memory usage: 897.8+ KB

# %% [markdown]
# Note that there are null in burn_material_amount

# %% [markdown]
# Convert times to datetime

# %%
times = ['scan_time', 'start_time', 'end_time', 'hotplate_start']
for t in times:
    df[t] = pd.to_datetime(df[t])

# %% [markdown]
# Convert burn_material_amount to float

# %%
df.burn_material_amount = df.burn_material_amount.str.strip('g').astype(float)
df.rename(columns={'burn_material_amount':'burn_material_amount(g)'},inplace=True)

# %% [markdown]
# Leave hotplate_temp as string since one of the values is "open fire."  These values will not be used for modeling anyway since these conditions won't exist in the field.

# %%
df.hotplate_temp.value_counts()
# Out:
# 500          1099
# 250           627
# open fire     428
# 320           344
# Name: hotplate_temp, dtype: int64

# %% [markdown]
# Leave distance_sensor_hotplate as a string also since it only takes on two values and it is synonymous with venue.

# %%
df.groupby(['distance_sensor_hotplate','venue_type']).count()
# Out:
#                                      sensor_node_id  scan_time  temp_0  \
# distance_sensor_hotplate venue_type
# 30m                      Hall                  1791       1791    1791
# 4m                       Chamber                707        707     707
#
#                                      temp_1  temp_2  temp_3  temp_4  temp_5  \
# distance_sensor_hotplate venue_type
# 30m                      Hall          1791    1791    1791    1791    1791
# 4m                       Chamber        707     707     707     707     707
#
#                                      temp_6  temp_7  ...  experiment_id  \
# distance_sensor_hotplate venue_type                  ...
# 30m                      Hall          1791    1791  ...           1791
# 4m                       Chamber        707     707  ...            707
#
#                                      start_time  end_time  burn_material  \
# distance_sensor_hotplate venue_type
# 30m                      Hall              1791      1791           1791
# 4m                       Chamber            707       707            707
#
#                                      burn_material_name  \
# distance_sensor_hotplate venue_type
# 30m                      Hall                      1791
# 4m                       Chamber                    707
#
#                                      burn_material_amount(g)  hotplate_start  \
# distance_sensor_hotplate venue_type
# 30m                      Hall                           1363            1791
# 4m                       Chamber                         707             707
#
#                                      hotplate_temp  venue  specimen_class
# distance_sensor_hotplate venue_type
# 30m                      Hall                 1791   1791            1791
# 4m                       Chamber               707    707             707
#
# [2 rows x 44 columns]

# %% [markdown]
# Encode specimen_class as encoded_specimen where:
#     in_smoke = 1
#     clean_air = 0

# %%
df.specimen_class.value_counts()
# Out:
# in_smoke     2017
# clean_air     481
# Name: specimen_class, dtype: int64

# %%
air_encode = {'in_smoke':1, 'clean_air':0}

# %%
df['encoded_specimen'] = df['specimen_class'].map(air_encode).astype(int)

# %%
df['encoded_specimen'].value_counts()
# Out:
# 1    2017
# 0     481
# Name: encoded_specimen, dtype: int64

# %%
df = df.drop(['specimen_class'], axis=1)

# %% [markdown]
# Leave burn_material and burn_material_name even though they are redundant because future groups might want the code or the name.

# %%
df.burn_material.value_counts()
# Out:
# SP2                                 1834
# Scott Pine branches in fire bowl     428
# BM2                                  236
# Name: burn_material, dtype: int64

# %%
df.groupby(['burn_material','burn_material_name']).count()
# Out:
#                                                                    sensor_node_id  \
# burn_material                    burn_material_name
# BM2                              BM2                                          236
# SP2                              SP2                                         1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl             428
#
#                                                                    scan_time  \
# burn_material                    burn_material_name
# BM2                              BM2                                     236
# SP2                              SP2                                    1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl        428
#
#                                                                    temp_0  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    temp_1  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    temp_2  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    temp_3  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    temp_4  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    temp_5  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    temp_6  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    temp_7  \
# burn_material                    burn_material_name
# BM2                              BM2                                  236
# SP2                              SP2                                 1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl     428
#
#                                                                    ...  \
# burn_material                    burn_material_name                ...
# BM2                              BM2                               ...
# SP2                              SP2                               ...
# Scott Pine branches in fire bowl Scott pine branches in fire bowl  ...
#
#                                                                    experiment_id  \
# burn_material                    burn_material_name
# BM2                              BM2                                         236
# SP2                              SP2                                        1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl            428
#
#                                                                    start_time  \
# burn_material                    burn_material_name
# BM2                              BM2                                      236
# SP2                              SP2                                     1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl         428
#
#                                                                    end_time  \
# burn_material                    burn_material_name
# BM2                              BM2                                    236
# SP2                              SP2                                   1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl       428
#
#                                                                    burn_material_amount(g)  \
# burn_material                    burn_material_name
# BM2                              BM2                                                   236
# SP2                              SP2                                                  1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl                        0
#
#                                                                    hotplate_start  \
# burn_material                    burn_material_name
# BM2                              BM2                                          236
# SP2                              SP2                                         1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl             428
#
#                                                                    hotplate_temp  \
# burn_material                    burn_material_name
# BM2                              BM2                                         236
# SP2                              SP2                                        1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl            428
#
#                                                                    distance_sensor_hotplate  \
# burn_material                    burn_material_name
# BM2                              BM2                                                    236
# SP2                              SP2                                                   1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl                       428
#
#                                                                    venue  \
# burn_material                    burn_material_name
# BM2                              BM2                                 236
# SP2                              SP2                                1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl    428
#
#                                                                    venue_type  \
# burn_material                    burn_material_name
# BM2                              BM2                                      236
# SP2                              SP2                                     1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl         428
#
#                                                                    encoded_specimen
# burn_material                    burn_material_name
# BM2                              BM2                                            236
# SP2                              SP2                                           1834
# Scott Pine branches in fire bowl Scott pine branches in fire bowl               428
#
# [3 rows x 44 columns]

# %%
df.drop('burn_material_name', axis=1, inplace=True)

# %% [markdown]
# One more check of data types ...

# %%
df.dtypes
# Out:
# sensor_node_id                       int64
# scan_time                   datetime64[ns]
# temp_0                             float64
# temp_1                             float64
# temp_2                             float64
# temp_3                             float64
# temp_4                             float64
# temp_5                             float64
# temp_6                             float64
# temp_7                             float64
# temp_8                             float64
# temp_9                             float64
# humid_0                            float64
# humid_1                            float64
# humid_2                            float64
# humid_3                            float64
# humid_4                            float64
# humid_5                            float64
# humid_6                            float64
# humid_7                            float64
# humid_8                            float64
# humid_9                            float64
# gas_scan_0                         float64
# gas_scan_1                         float64
# gas_scan_2                         float64
# gas_scan_3                         float64
# gas_scan_4                         float64
# gas_scan_5                         float64
# gas_scan_6                         float64
# gas_scan_7                         float64
# gas_scan_8                         float64
# gas_scan_9                         float64
# gas_scan_cnt                       float64
# trigger                             object
# experiment_id                        int64
# start_time                  datetime64[ns]
# end_time                    datetime64[ns]
# burn_material                       object
# burn_material_amount(g)            float64
# hotplate_start              datetime64[ns]
# hotplate_temp                       object
# distance_sensor_hotplate            object
# venue                               object
# venue_type                          object
# encoded_specimen                     int32
# dtype: object

# %%
df.to_csv(output_file, index = False, header = True)
