# %% [markdown]
# # Loading libraries

# %%
from pycaret.classification import *
from pycaret.datasets import get_data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = get_data("diabetes")
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %% [markdown]
# # Exploring data

# %%
df.columns.array
# Out:
# <PandasArray>
# [                                                'Number of times pregnant',
#  'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#                                          'Diastolic blood pressure (mm Hg)',
#                                          'Triceps skin fold thickness (mm)',
#                                            '2-Hour serum insulin (mu U/ml)',
#                            'Body mass index (weight in kg/(height in m)^2)',
#                                                'Diabetes pedigree function',
#                                                               'Age (years)',
#                                                            'Class variable']
# Length: 9, dtype: object

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.105469                         20.536458
# std                           19.355807                         15.952218
# min                            0.000000                          0.000000
# 25%                           62.000000                          0.000000
# 50%                           72.000000                         23.000000
# 75%                           80.000000                         32.000000
# max                          122.000000                         99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function  Age (years)  Class variable
# count                  768.000000   768.000000      768.000000
# mean                     0.471876    33.240885        0.348958
# std                      0.331329    11.760232        0.476951
# min                      0.078000    21.000000        0.000000
# 25%                      0.243750    24.000000        0.000000
# 50%                      0.372500    29.000000        0.000000
# 75%                      0.626250    41.000000        1.000000
# max                      2.420000    81.000000        1.000000

# %% [markdown]
# ## Looking into the missing values

# %%
plt.figure(figsize=(16,7)) # seems like our data have missing values !
sns.heatmap(df.isna().transpose())
# Out:
# <AxesSubplot:>

# %%
classifier = setup(data = df, target ="Class variable")
# Out:
# <style type="text/css">
# #T_2578c_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2578c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2578c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2578c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_2578c_row0_col1" class="data row0 col1" >5428</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2578c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2578c_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2578c_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_2578c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2578c_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_2578c_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2578c_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_2578c_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2578c_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_2578c_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2578c_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_2578c_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2578c_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_2578c_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2578c_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_2578c_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2578c_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_2578c_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2578c_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_2578c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2578c_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_2578c_row11_col1" class="data row11 col1" >(537, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2578c_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_2578c_row12_col1" class="data row12 col1" >(231, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2578c_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_2578c_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2578c_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_2578c_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2578c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_2578c_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2578c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_2578c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2578c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_2578c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2578c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_2578c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2578c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_2578c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2578c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_2578c_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2578c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_2578c_row21_col1" class="data row21 col1" >532b</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2578c_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_2578c_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2578c_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_2578c_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_2578c_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_2578c_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_2578c_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_2578c_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_2578c_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_2578c_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_2578c_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_2578c_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_2578c_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_2578c_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_2578c_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_2578c_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2578c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_2578c_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_2578c_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <t

# %% [markdown]
# # Lets compare models

# %%
compare_models() # Figures shows the clear winner is logistic regression.
# Out:
# <style type="text/css">
# #T_f8e1e_ th {
#   text-align: left;
# }
# #T_f8e1e_row0_col0, #T_f8e1e_row0_col2, #T_f8e1e_row0_col3, #T_f8e1e_row1_col0, #T_f8e1e_row1_col1, #T_f8e1e_row1_col2, #T_f8e1e_row1_col3, #T_f8e1e_row1_col4, #T_f8e1e_row1_col5, #T_f8e1e_row1_col6, #T_f8e1e_row1_col7, #T_f8e1e_row2_col0, #T_f8e1e_row2_col1, #T_f8e1e_row2_col3, #T_f8e1e_row2_col4, #T_f8e1e_row2_col5, #T_f8e1e_row2_col6, #T_f8e1e_row2_col7, #T_f8e1e_row3_col0, #T_f8e1e_row3_col1, #T_f8e1e_row3_col2, #T_f8e1e_row3_col3, #T_f8e1e_row3_col4, #T_f8e1e_row3_col5, #T_f8e1e_row3_col6, #T_f8e1e_row3_col7, #T_f8e1e_row4_col0, #T_f8e1e_row4_col1, #T_f8e1e_row4_col2, #T_f8e1e_row4_col3, #T_f8e1e_row4_col4, #T_f8e1e_row4_col5, #T_f8e1e_row4_col6, #T_f8e1e_row4_col7, #T_f8e1e_row5_col0, #T_f8e1e_row5_col1, #T_f8e1e_row5_col2, #T_f8e1e_row5_col3, #T_f8e1e_row5_col4, #T_f8e1e_row5_col5, #T_f8e1e_row5_col6, #T_f8e1e_row5_col7, #T_f8e1e_row6_col0, #T_f8e1e_row6_col1, #T_f8e1e_row6_col2, #T_f8e1e_row6_col3, #T_f8e1e_row6_col4, #T_f8e1e_row6_col5, #T_f8e1e_row6_col6, #T_f8e1e_row6_col7, #T_f8e1e_row7_col0, #T_f8e1e_row7_col1, #T_f8e1e_row7_col2, #T_f8e1e_row7_col3, #T_f8e1e_row7_col4, #T_f8e1e_row7_col5, #T_f8e1e_row7_col6, #T_f8e1e_row7_col7, #T_f8e1e_row8_col0, #T_f8e1e_row8_col1, #T_f8e1e_row8_col2, #T_f8e1e_row8_col3, #T_f8e1e_row8_col4, #T_f8e1e_row8_col5, #T_f8e1e_row8_col6, #T_f8e1e_row8_col7, #T_f8e1e_row9_col0, #T_f8e1e_row9_col1, #T_f8e1e_row9_col2, #T_f8e1e_row9_col3, #T_f8e1e_row9_col4, #T_f8e1e_row9_col5, #T_f8e1e_row9_col6, #T_f8e1e_row9_col7, #T_f8e1e_row10_col0, #T_f8e1e_row10_col1, #T_f8e1e_row10_col2, #T_f8e1e_row10_col3, #T_f8e1e_row10_col4, #T_f8e1e_row10_col5, #T_f8e1e_row10_col6, #T_f8e1e_row10_col7, #T_f8e1e_row11_col0, #T_f8e1e_row11_col1, #T_f8e1e_row11_col2, #T_f8e1e_row11_col3, #T_f8e1e_row11_col4, #T_f8e1e_row11_col5, #T_f8e1e_row11_col6, #T_f8e1e_row11_col7, #T_f8e1e_row12_col0, #T_f8e1e_row12_col1, #T_f8e1e_row12_col2, #T_f8e1e_row12_col4, #T_f8e1e_row12_col5, #T_f8e1e_row12_col6, #T_f8e1e_row12_col7 {
#   text-align: left;
# }
# #T_f8e1e_row0_col1, #T_f8e1e_row0_col4, #T_f8e1e_row0_col5, #T_f8e1e_row0_col6, #T_f8e1e_row0_col7, #T_f8e1e_row2_col2, #T_f8e1e_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f8e1e_row0_col8, #T_f8e1e_row1_col8, #T_f8e1e_row2_col8, #T_f8e1e_row3_col8, #T_f8e1e_row4_col8, #T_f8e1e_row5_col8, #T_f8e1e_row6_col8, #T_f8e1e_row7_col8, #T_f8e1e_row8_col8, #T_f8e1e_row9_col8, #T_f8e1e_row11_col8, #T_f8e1e_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f8e1e_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f8e1e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8e1e_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_f8e1e_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_f8e1e_row0_col1" class="data row0 col1" >0.7582</td>
#       <td id="T_f8e1e_row0_col2" class="data row0 col2" >0.8107</td>
#       <td id="T_f8e1e_row0_col3" class="data row0 col3" >0.5471</td>
#       <td id="T_f8e1e_row0_col4" class="data row0 col4" >0.6821</td>
#       <td id="T_f8e1e_row0_col5" class="data row0 col5" >0.6020</td>
#       <td id="T_f8e1e_row0_col6" class="data row0 col6" >0.4322</td>
#       <td id="T_f8e1e_row0_col7" class="data row0 col7" >0.4412</td>
#       <td id="T_f8e1e_row0_col8" class="data row0 col8" >1.6710</td>
#     </tr>
#     <tr>
#       <th id="T